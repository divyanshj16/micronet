# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import fastai

# %%
from pathlib import Path
import pickle
from PIL import Image

import matplotlib.pyplot as plt

from fastai.vision import ImageDataBunch
from fastai.vision import LabelLists
from fastai.vision import get_transforms

# %%
import torch, fastai
torch.__version__, fastai.__version__
# Out:
# ('1.1.0', '1.0.58')

# %%
cifar100_stats = (torch.tensor([0.5070751592371323, 0.48654887331495095, 0.4409178433670343]),
 torch.tensor([0.26733428587924035, 0.2564384629170881, 0.2761504713256853]))

# %%
path = Path('cifar100')
train_file = 'train'
test_file = 'test'

# %%
get_transforms()
# Out:
# ([RandTransform(tfm=TfmCrop (crop_pad), kwargs={'row_pct': (0, 1), 'col_pct': (0, 1), 'padding_mode': 'reflection'}, p=1.0, resolved={}, do_run=True, is_random=True, use_on_y=True),
#   RandTransform(tfm=TfmPixel (flip_lr), kwargs={}, p=0.5, resolved={}, do_run=True, is_random=True, use_on_y=True),
#   RandTransform(tfm=TfmCoord (symmetric_warp), kwargs={'magnitude': (-0.2, 0.2)}, p=0.75, resolved={}, do_run=True, is_random=True, use_on_y=True),
#   RandTransform(tfm=TfmAffine (rotate), kwargs={'degrees': (-10.0, 10.0)}, p=0.75, resolved={}, do_run=True, is_random=True, use_on_y=True),
#   RandTransform(tfm=TfmAffine (zoom), kwargs={'scale': (1.0, 1.1), 'row_pct': (0, 1), 'col_pct': (0, 1)}, p=0.75, resolved={}, do_run=True, is_random=True, use_on_y=True),
#   RandTransform(tfm=TfmLighting (brightness), kwargs={'change': (0.4, 0.6)}, p=0.75, resolved={}, do_run=True, is_random=True, use_on_y=True),
#   RandTransform(tfm=TfmLighting (contrast), kwargs={'scale': (0.8, 1.25)}, p=0.75, resolved={}, do_run=True, is_random=True, use_on_y=True)],
#  [RandTransform(tfm=TfmCrop (crop_pad), kwargs={}, p=1.0, resolved={}, do_run=True, is_random=True, use_on_y=True)])

# %%
data = ImageDataBunch.from_folder(path,
                                  train=f'train_data',
                                  valid=f'valid_data',
                                  ds_tfms=get_transforms(),
                                  num_workers=10,
                                  bs=1024,
                                 ).normalize(cifar100_stats)

# %%
# %%time
data.show_batch()
# Out:
# CPU times: user 2.07 s, sys: 47 ms, total: 2.12 s
# Wall time: 1.22 s

# %%
from torchvision import models
from fastai.vision import cnn_learner, accuracy, create_body
from fastai.callbacks import model_sizes, hook_outputs

# %%
from torch import nn
from torchsummary import summary
import numpy as np

# %%
# from drn import drn_d_24

# %%
# def get_hook_idxs(module):
#     "Get the indexes of the layers where the size of the activation changes."
#     sizes = model_sizes(module, size=(32, 32))
#     feature_szs = [size[-1] for size in sizes]
#     sfs_idxs = list(np.where(np.array(feature_szs[:-1]) != np.array(feature_szs[1:]))[0])
#     if feature_szs[0] != feature_szs[1]: sfs_idxs = [0] + sfs_idxs
#     return sfs_idxs

# %%
# class Mod(nn.Module):
#     def __init__(self, backbone_fn, num_classes=100, middle_size=64, **kwargs):
#         super().__init__()
#         self.backbone = create_body(backbone_fn, **kwargs)
#         self.sizes = model_sizes(self.backbone, size=(32, 32))
#         self.hook_idxs = get_hook_idxs(self.backbone)
#         self.hooks = hook_outputs([self.backbone[i] for i in self.hook_idxs])
#         self.convs = nn.ModuleList([nn.Sequential(nn.Conv2d(self.sizes[s][1], middle_size, kernel_size=3, padding=1),
#                                                   nn.BatchNorm2d(middle_size),
#                                                   nn.ReLU(inplace=True),
#                                                   nn.AdaptiveAvgPool2d(1)
#                                    ) for s in self.hook_idxs])
        
#         final_in = middle_size * len(self.hook_idxs) + self.sizes[-1][1]
#         self.final = nn.Conv2d(final_in, num_classes, kernel_size=1)
        
        
#     def forward(self, inp):
#         feats = [self.backbone(inp)]
#         for i, conv in enumerate(self.convs):
#             feats.append(conv(self.hooks[i].stored))
#         self.remove()
#         final_feats = torch.cat(feats, 1)        
#         return self.final(final_feats).squeeze()
        
#     def remove(self):
#         torch.cuda.empty_cache()
#         for hook in self.hooks:
#             del hook.stored

# %%
# a = model.hooks[0].stored

# %%
# learn.pred_batch()

# %%
# b = learn.model.hooks[0].stored

# %%
# (a - b).sum()

# %%
# model = Mod(drn_d_24, pretrained=False, cut=-1)

# %%
from efficientnet_pytorch import EfficientNet

# %%
model = EfficientNet.from_name('efficientnet-b1', {'num_classes': 100})

# %%
from fastai.basic_train import Learner

# %%
learn = Learner(data, model, metrics=[accuracy]).mixup()

# %%
learn.summary()
# Out:
# EfficientNet
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# ZeroPad2d            [3, 33, 33]          0          False
# ______________________________________________________________________
# BatchNorm2d          [32, 16, 16]         64         True
# ______________________________________________________________________
# ZeroPad2d            [32, 18, 18]         0          False
# ______________________________________________________________________
# BatchNorm2d          [32, 16, 16]         64         True
# ______________________________________________________________________
# Identity             [32, 1, 1]           0          False
# ______________________________________________________________________
# Identity             [8, 1, 1]            0          False
# ______________________________________________________________________
# Identity             [32, 16, 16]         0          False
# ______________________________________________________________________
# BatchNorm2d          [16, 16, 16]         32         True
# ______________________________________________________________________
# ZeroPad2d            [16, 18, 18]         0          False
# ______________________________________________________________________
# BatchNorm2d          [16, 16, 16]         32         True
# ______________________________________________________________________
# Identity             [16, 1, 1]           0          False
# ______________________________________________________________________
# Identity             [4, 1, 1]            0          False
# ______________________________________________________________________
# Identity             [16, 16, 16]         0          False
# ______________________________________________________________________
# BatchNorm2d          [16, 16, 16]         32         True
# ______________________________________________________________________
# Identity             [16, 16, 16]         0          False
# ______________________________________________________________________
# BatchNorm2d          [96, 16, 16]         192        True
# ______________________________________________________________________
# ZeroPad2d            [96, 17, 17]         0          False
# ______________________________________________________________________
# BatchNorm2d          [96, 8, 8]           192        True
# ______________________________________________________________________
# Identity             [96, 1, 1]           0          False
# ______________________________________________________________________
# Identity             [4, 1, 1]            0          False
# ______________________________________________________________________
# Identity             [96, 8, 8]           0          False
# ______________________________________________________________________
# BatchNorm2d          [24, 8, 8]           48         True
# ______________________________________________________________________
# Identity             [24, 8, 8]           0          False
# ______________________________________________________________________
# BatchNorm2d          [144, 8, 8]          288        True
# ______________________________________________________________________
# ZeroPad2d            [144, 10, 10]        0          False
# ______________________________________________________________________
# BatchNorm2d          [144, 8, 8]          288        True
# ______________________________________________________________________
# Identity             [144, 1, 1]          0          False
# ______________________________________________________________________
# Identity             [6, 1, 1]            0          False
# ______________________________________________________________________
# Identity             [144, 8, 8]          0          False
# ______________________________________________________________________
# BatchNorm2d          [24, 8, 8]           48         True
# ______________________________________________________________________
# Identity             [24, 8, 8]           0          False
# ______________________________________________________________________
# BatchNorm2d          [144, 8, 8]          288        True
# ______________________________________________________________________
# ZeroPad2d            [144, 10, 10]        0          False
# ______________________________________________________________________
# BatchNorm2d          [144, 8, 8]          288        True
# ______________________________________________________________________
# Identity             [144, 1, 1]          0          False
# ______________________________________________________________________
# Identity             [6, 1, 1]            0          False
# ______________________________________________________________________
# Identity             [144, 8, 8]          0          False
# ______________________________________________________________________
# BatchNorm2d          [24, 8, 8]           48         True
# ______________________________________________________________________
# Identity             [24, 8, 8]           0          False
# ______________________________________________________________________
# BatchNorm2d          [144, 8, 8]          288        True
# ______________________________________________________________________
# ZeroPad2d            [144, 11, 11]        0          False
# ______________________________________________________________________
# BatchNorm2d          [144, 4, 4]          288        True
# ______________________________________________________________________
# Identity             [144, 1, 1]          0          False
# ______________________________________________________________________
# Identity             [6, 1, 1]            0          False
# ______________________________________________________________________
# Identity             [144, 4, 4]          0          False
# ______________________________________________________________________
# BatchNorm2d          [40, 4, 4]           80         True
# ______________________________________________________________________
# Identity             [40, 4, 4]           0          False
# ______________________________________________________________________
# BatchNorm2d          [240, 4, 4]          480        True
# ______________________________________________________________________
# ZeroPad2d            [240, 8, 8]          0          False
# ______________________________________________________________________
# BatchNorm2d          [240, 4, 4]          480        True
# ______________________________________________________________________
# Identity             [240, 1, 1]          0          False
# ______________________________________________________________________
# Identity             [10, 1, 1]           0          False
# ______________________________________________________________________
# Identity             [240, 4, 4]          0          False
# ______________________________________________________________________
# BatchNorm2d          [40, 4, 4]           80         True
# ______________________________________________________________________
# Identity             [40, 4, 4]           0          False
# ______________________________________________________________________
# BatchNorm2d          [240, 4, 4]          480        True
# ______________________________________________________________________
# ZeroPad2d            [240, 8, 8]          0          False
# ______________________________________________________________________
# BatchNorm2d          [240, 4, 4]          480        True
# ______________________________________________________________________
# Identity             [240, 1, 1]          0          False
# ______________________________________________________________________
# Identity             [10, 1, 1]           0          False
# ______________________________________________________________________
# Identity             [240, 4, 4]          0          False
# ______________________________________________________________________
# BatchNorm2d          [40, 4, 4]           80         True
# ______________________________________________________________________
# Identity             [40, 4, 4]           0          False
# ______________________________________________________________________
# BatchNorm2d          [240, 4, 4]          480        True
# ______________________________________________________________________
# ZeroPad2d            [240, 5, 5]          0          False
# ______________________________________________________________________
# BatchNorm2d          [240, 2, 2]          480        True
# ______________________________________________________________________
# Identity             [240, 1, 1]          0          False
# ______________________________________________________________________
# Identity             [10, 1, 1]           0          False
# ______________________________________________________________________
# Identity             [240, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [80, 2, 2]           160        True
# ______________________________________________________________________
# Identity             [80, 2, 2]           0          False
# ______________________________________________________________________
# BatchNorm2d          [480, 2, 2]          960        True
# ______________________________________________________________________
# ZeroPad2d            [480, 4, 4]          0          False
# ______________________________________________________________________
# BatchNorm2d          [480, 2, 2]          960        True
# ______________________________________________________________________
# Identity             [480, 1, 1]          0          False
# ______________________________________________________________________
# Identity             [20, 1, 1]           0          False
# ______________________________________________________________________
# Identity             [480, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [80, 2, 2]           160        True
# ______________________________________________________________________
# Identity             [80, 2, 2]           0          False
# ______________________________________________________________________
# BatchNorm2d          [480, 2, 2]          960        True
# ______________________________________________________________________
# ZeroPad2d            [480, 4, 4]          0          False
# ______________________________________________________________________
# BatchNorm2d          [480, 2, 2]          960        True
# ______________________________________________________________________
# Identity             [480, 1, 1]          0          False
# ______________________________________________________________________
# Identity             [20, 1, 1]           0          False
# ______________________________________________________________________
# Identity             [480, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [80, 2, 2]           160        True
# ______________________________________________________________________
# Identity             [80, 2, 2]           0          False
# ______________________________________________________________________
# BatchNorm2d          [480, 2, 2]          960        True
# ______________________________________________________________________
# ZeroPad2d            [480, 4, 4]          0          False
# ______________________________________________________________________
# BatchNorm2d          [480, 2, 2]          960        True
# ______________________________________________________________________
# Identity             [480, 1, 1]          0          False
# ______________________________________________________________________
# Identity             [20, 1, 1]           0          False
# ______________________________________________________________________
# Identity             [480, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [80, 2, 2]           160        True
# ______________________________________________________________________
# Identity             [80, 2, 2]           0          False
# ______________________________________________________________________
# BatchNorm2d          [480, 2, 2]          960        True
# ______________________________________________________________________
# ZeroPad2d            [480, 6, 6]          0          False
# ______________________________________________________________________
# BatchNorm2d          [480, 2, 2]          960        True
# ______________________________________________________________________
# Identity             [480, 1, 1]          0          False
# ______________________________________________________________________
# Identity             [20, 1, 1]           0          False
# ______________________________________________________________________
# Identity             [480, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [112, 2, 2]          224        True
# ______________________________________________________________________
# Identity             [112, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [672, 2, 2]          1,344      True
# ______________________________________________________________________
# ZeroPad2d            [672, 6, 6]          0          False
# ______________________________________________________________________
# BatchNorm2d          [672, 2, 2]          1,344      True
# ______________________________________________________________________
# Identity             [672, 1, 1]          0          False
# ______________________________________________________________________
# Identity             [28, 1, 1]           0          False
# ______________________________________________________________________
# Identity             [672, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [112, 2, 2]          224        True
# ______________________________________________________________________
# Identity             [112, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [672, 2, 2]          1,344      True
# ______________________________________________________________________
# ZeroPad2d            [672, 6, 6]          0          False
# ______________________________________________________________________
# BatchNorm2d          [672, 2, 2]          1,344      True
# ______________________________________________________________________
# Identity             [672, 1, 1]          0          False
# ______________________________________________________________________
# Identity             [28, 1, 1]           0          False
# ______________________________________________________________________
# Identity             [672, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [112, 2, 2]          224        True
# ______________________________________________________________________
# Identity             [112, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [672, 2, 2]          1,344      True
# ______________________________________________________________________
# ZeroPad2d            [672, 6, 6]          0          False
# ______________________________________________________________________
# BatchNorm2d          [672, 2, 2]          1,344      True
# ______________________________________________________________________
# Identity             [672, 1, 1]          0          False
# ______________________________________________________________________
# Identity             [28, 1, 1]           0          False
# ______________________________________________________________________
# Identity             [672, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [112, 2, 2]          224        True
# ______________________________________________________________________
# Identity             [112, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [672, 2, 2]          1,344      True
# ______________________________________________________________________
# ZeroPad2d            [672, 5, 5]          0          False
# ______________________________________________________________________
# BatchNorm2d          [672, 1, 1]          1,344      True
# ______________________________________________________________________
# Identity             [672, 1, 1]          0          False
# ______________________________________________________________________
# Identity             [28, 1, 1]           0          False
# ______________________________________________________________________
# Identity             [672, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [192, 1, 1]          384        True
# ______________________________________________________________________
# Identity             [192, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [1152, 1, 1]         2,304      True
# ______________________________________________________________________
# ZeroPad2d            [1152, 5, 5]         0          False
# ______________________________________________________________________
# BatchNorm2d          [1152, 1, 1]         2,304      True
# ______________________________________________________________________
# Identity             [1152, 1, 1]         0          False
# ______________________________________________________________________
# Identity             [48, 1, 1]           0          False
# ______________________________________________________________________
# Identity             [1152, 1, 1]         0          False
# ______________________________________________________________________
# BatchNorm2d          [192, 1, 1]          384        True
# ______________________________________________________________________
# Identity             [192, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [1152, 1, 1]         2,304      True
# ______________________________________________________________________
# ZeroPad2d            [1152, 5, 5]         0          False
# ______________________________________________________________________
# BatchNorm2d          [1152, 1, 1]         2,304      True
# ______________________________________________________________________
# Identity             [1152, 1, 1]         0          False
# ______________________________________________________________________
# Identity             [48, 1, 1]           0          False
# ______________________________________________________________________
# Identity             [1152, 1, 1]         0          False
# ______________________________________________________________________
# BatchNorm2d          [192, 1, 1]          384        True
# ______________________________________________________________________
# Identity             [192, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [1152, 1, 1]         2,304      True
# ______________________________________________________________________
# ZeroPad2d            [1152, 5, 5]         0          False
# ______________________________________________________________________
# BatchNorm2d          [1152, 1, 1]         2,304      True
# ______________________________________________________________________
# Identity             [1152, 1, 1]         0          False
# ______________________________________________________________________
# Identity             [48, 1, 1]           0          False
# ______________________________________________________________________
# Identity             [1152, 1, 1]         0          False
# ______________________________________________________________________
# BatchNorm2d          [192, 1, 1]          384        True
# ______________________________________________________________________
# Identity             [192, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [1152, 1, 1]         2,304      True
# ______________________________________________________________________
# ZeroPad2d            [1152, 5, 5]         0          False
# ______________________________________________________________________
# BatchNorm2d          [1152, 1, 1]         2,304      True
# ______________________________________________________________________
# Identity             [1152, 1, 1]         0          False
# ______________________________________________________________________
# Identity             [48, 1, 1]           0          False
# ______________________________________________________________________
# Identity             [1152, 1, 1]         0          False
# ______________________________________________________________________
# BatchNorm2d          [192, 1, 1]          384        True
# ______________________________________________________________________
# Identity             [192, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [1152, 1, 1]         2,304      True
# ______________________________________________________________________
# ZeroPad2d            [1152, 3, 3]         0          False
# ______________________________________________________________________
# BatchNorm2d          [1152, 1, 1]         2,304      True
# ______________________________________________________________________
# Identity             [1152, 1, 1]         0          False
# ______________________________________________________________________
# Identity             [48, 1, 1]           0          False
# ______________________________________________________________________
# Identity             [1152, 1, 1]         0          False
# ______________________________________________________________________
# BatchNorm2d          [320, 1, 1]          640        True
# ______________________________________________________________________
# Identity             [320, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [1920, 1, 1]         3,840      True
# ______________________________________________________________________
# ZeroPad2d            [1920, 3, 3]         0          False
# ______________________________________________________________________
# BatchNorm2d          [1920, 1, 1]         3,840      True
# ______________________________________________________________________
# Identity             [1920, 1, 1]         0          False
# ______________________________________________________________________
# Identity             [80, 1, 1]           0          False
# ______________________________________________________________________
# Identity             [1920, 1, 1]         0          False
# ______________________________________________________________________
# BatchNorm2d          [320, 1, 1]          640        True
# ______________________________________________________________________
# Identity             [320, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [1280, 1, 1]         2,560      True
# ______________________________________________________________________
# Linear               [100]                128,100    True
# ______________________________________________________________________
#
# Total params: 190,148
# Total trainable params: 190,148
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied

# %%
# learn = cnn_learner(data, drn_d_24, metrics=[accuracy], pretrained=False).mixup()

# %%
# for n, m in learn.model.named_parameters():
#     print(m.requires_grad)

# %%
# learn.summary()

# %%
# summary(learn.model, input_size=(3, 32, 32))

# %%
from fastai.callbacks import SaveModelCallback
from torch import nn
import torch.nn.functional as F

# %% [markdown]
# ####  Focal Loss

# %%
## code from http://www.hawia.xyz/2019/01/12/Losses%20of%20Pytorch%20and%20Focal%20Loss/

class FocalLoss(nn.Module):
    def __init__(self, gamma=2, weight=None):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.weight = weight

    def forward(self, input, target, reduction):
        """
        input: [N, C], float32
        target: [N, ], int64
        """
        logpt = F.log_softmax(input, dim=1)
        pt = torch.exp(logpt)
        logpt = (1-pt) ** self.gamma * logpt
        loss = F.nll_loss(logpt, target, self.weight, reduction)
        return loss

# %%
# set focal loss
focal_loss = FocalLoss()
learn.loss_func = focal_loss

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# class RemoveHookCallback

# %%
import warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    learn.fit_one_cycle(500, 2e-3, callbacks=SaveModelCallback(learn, name='efficient_net', ), wd=0.1)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='500', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.40% [2/500 01:09<4:46:26]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.457190</td>
#       <td>4.513689</td>
#       <td>0.010000</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.261147</td>
#       <td>4.514392</td>
#       <td>0.010000</td>
#       <td>00:35</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='195', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Better model found at epoch 0 with valid_loss value: 4.513689041137695.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.conda/envs/torch/lib/python3.7/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      98             cb_handler.on_epoch_begin()
# ---> 99             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/fastprogress/fastprogress.py in __iter__(self)
#      74                 yield o
# ---> 75                 if self.auto_update: self.update(i+1)
#      76         except:
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/fastprogress/fastprogress.py in update(self, val)
#      91             self.last_v,self.last_t = val,cur_t
# ---> 92             self.update_bar(val)
#      93             if not self.auto_update and val >= self.total:
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/fastprogress/fastprogress.py in update_bar(self, val)
#     103             self.on_update(0, '100% [0/0]')
# --> 104         else: self.on_update(val, f'{100 * val/self.total:.2f}% [{val}/{self.total} {elapsed_t}<{remaining_t}{end}]')
#     105
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/fastprogress/fastprogress.py in on_update(self, val, text, interrupted)
#     176         if self.display: self.out.update(HTML(self.progress))
# --> 177         elif self.parent is not None: self.parent.show()
#     178
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/fastprogress/fastprogress.py in show(self)
#     215         self.html_code = '\n'.join([self.inner_dict[n] for n in to_show])
# --> 216         self.out.update(HTML(self.html_code))
#     217
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/IPython/core/display.py in update(self, obj, **kwargs)
#     385         """
# --> 386         update_display(obj, display_id=self.display_id, **kwargs)
#     387
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/IPython/core/display.py in update_display(obj, display_id, **kwargs)
#     335     kwargs['update'] = True
# --> 336     display(obj, display_id=display_id, **kwargs)
#     337
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     312                 _merge(md_dict, metadata)
# --> 313             publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     314     if display_id:
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/IPython/core/display.py in publish_display_data(data, metadata, source, transient, **kwargs)
#     121         metadata=metadata,
# --> 122         **kwargs
#     123     )
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/ipykernel/zmqshell.py in publish(self, data, metadata, source, transient, update)
#     141         self.session.send(
# --> 142             self.pub_socket, msg, ident=self.topic,
#     143         )
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/jupyter_client/session.py in send(self, stream, msg_or_type, content, parent, ident, buffers, track, header, metadata)
#     747             tracker = DONE
# --> 748             stream.send_multipart(to_send, copy=copy)
#     749
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/ipykernel/iostream.py in send_multipart(self, *args, **kwargs)
#     261         """Schedule send in IO thread"""
# --> 262         return self.io_thread.send_multipart(*args, **kwargs)
#     263
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/ipykernel/iostream.py in send_multipart(self, *args, **kwargs)
#     211         """
# --> 212         self.schedule(lambda : self._really_send(*args, **kwargs))
#     213
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/ipykernel/iostream.py in schedule(self, f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     394             data.group = group
# --> 395         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     396
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-2a9d095c3f7f> in <module>
#       2 with warnings.catch_warnings():
#       3     warnings.simplefilter("ignore")
# ----> 4     learn.fit_one_cycle(500, 2e-3, callbacks=SaveModelCallback(learn, name='efficient_net'), wd=0.1)
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, final_div, wd, callbacks, tot_epochs, start_epoch)
#      21     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor, pct_start=pct_start,
#      22                                        final_div=final_div, tot_epochs=tot_epochs, start_epoch=start_epoch))
# ---> 23     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      24
#      25 def fit_fc(learn:Learner, tot_epochs:int=1, lr:float=defaults.lr,  moms:Tuple[float,float]=(0.95,0.85), start_pct:float=0.72,
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     198         else: self.opt.lr,self.opt.wd = lr,wd
#     199         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
# --> 200         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     201
#     202     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#     110         exception = e
#     111         raise
# --> 112     finally: cb_handler.on_train_end(exception)
#     113
#     114 loss_func_name2activ = {'cross_entropy_loss': F.softmax, 'nll_loss': torch.exp, 'poisson_nll_loss': torch.exp,
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/fastai/callback.py in on_train_end(self, exception)
#     321     def on_train_end(self, exception:Union[bool,Exception])->None:
#     322         "Handle end of training, `exception` is an `Exception` or False if no exceptions during training."
# --> 323         self('train_end', exception=exception)
#     324
#     325     @property
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/fastai/callback.py in __call__(self, cb_name, call_mets, **kwargs)
#     249         if call_mets:
#     250             for met in self.metrics: self._call_and_update(met, cb_name, **kwargs)
# --> 251         for cb in self.callbacks: self._call_and_update(cb, cb_name, **kwargs)
#     252
#     253     def set_dl(self, dl:DataLoader):
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/fastai/callback.py in _call_and_update(self, cb, cb_name, **kwargs)
#     239     def _call_and_update(self, cb, cb_name, **kwargs)->None:
#     240         "Call `cb_name` on `cb` and update the inner state."
# --> 241         new = ifnone(getattr(cb, f'on_{cb_name}')(**self.state_dict, **kwargs), dict())
#     242         for k,v in new.items():
#     243             if k not in self.state_dict:
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/fastai/callbacks/tracker.py in on_train_end(self, **kwargs)
#     103         "Load the best model."
#     104         if self.every=="improvement" and (self.learn.path/f'{self.learn.model_dir}/{self.name}.pth').is_file():
# --> 105             self.learn.load(f'{self.name}', purge=False)
#     106
#     107 class ReduceLROnPlateauCallback(TrackerCallback):
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/fastai/basic_train.py in load(self, file, device, strict, with_opt, purge, remove_module)
#     279             get_model(self.model).load_state_dict(state, strict=strict)
#     280         del state
# --> 281         gc.collect()
#     282         return self
#     283
#
# KeyboardInterrupt:

# %%
# learn.save('DRNET22-200')

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# /home/divyansh/.conda/envs/torch/lib/python3.7/site-packages/torch/nn/_reduction.py:46: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
import warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    learn.fit_one_cycle(200, 1e-3, callbacks=SaveModelCallback(learn, name='DRNET22'), wd=0.1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.334570</td>
#       <td>1.139792</td>
#       <td>0.672500</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.325988</td>
#       <td>1.138140</td>
#       <td>0.672600</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.322971</td>
#       <td>1.140874</td>
#       <td>0.673700</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.324074</td>
#       <td>1.142497</td>
#       <td>0.671800</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.325206</td>
#       <td>1.141055</td>
#       <td>0.672800</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.316245</td>
#       <td>1.138631</td>
#       <td>0.673500</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.318240</td>
#       <td>1.142995</td>
#       <td>0.672700</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.311314</td>
#       <td>1.141441</td>
#       <td>0.672700</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.313173</td>
#       <td>1.142094</td>
#       <td>0.673700</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.314234</td>
#       <td>1.135544</td>
#       <td>0.674100</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.304887</td>
#       <td>1.140082</td>
#       <td>0.672100</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.306298</td>
#       <td>1.145111</td>
#       <td>0.675100</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.308139</td>
#       <td>1.144758</td>
#       <td>0.672400</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.313576</td>
#       <td>1.145541</td>
#       <td>0.670500</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.310497</td>
#       <td>1.142981</td>
#       <td>0.673400</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.303116</td>
#       <td>1.141121</td>
#       <td>0.673500</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.306337</td>
#       <td>1.142046</td>
#       <td>0.676300</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.301411</td>
#       <td>1.134139</td>
#       <td>0.676800</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.308691</td>
#       <td>1.149468</td>
#       <td>0.673500</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.304597</td>
#       <td>1.147360</td>
#       <td>0.675200</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.305340</td>
#       <td>1.143324</td>
#       <td>0.673900</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.304597</td>
#       <td>1.146769</td>
#       <td>0.675200</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.309934</td>
#       <td>1.145049</td>
#       <td>0.674700</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.308411</td>
#       <td>1.159702</td>
#       <td>0.670500</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.308478</td>
#       <td>1.157891</td>
#       <td>0.674200</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.316188</td>
#       <td>1.156735</td>
#       <td>0.672400</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.313779</td>
#       <td>1.158128</td>
#       <td>0.674400</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.306343</td>
#       <td>1.141828</td>
#       <td>0.676100</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.302469</td>
#       <td>1.167766</td>
#       <td>0.669200</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1
td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>1.224410</td>
#       <td>1.384090</td>
#       <td>0.677300</td>
#       <td>0
# Better model found at epoch 0 with valid_loss value: 1.4295111894607544.
# Better model found at epoch 1 with valid_loss value: 1.4133862257003784.
# Better model found at epoch 2 with valid_loss value: 1.3957982063293457.
# Better model found at epoch 3 with valid_loss value: 1.3795428276062012.
# Better model found at epoch 4 with valid_loss value: 1.3648756742477417.
# Better model found at epoch 5 with valid_loss value: 1.3542433977127075.
# Better model found at epoch 6 with valid_loss value: 1.3439967632293701.
# Better model found at epoch 7 with valid_loss value: 1.3369300365447998.
# Better model found at epoch 8 with valid_loss value: 1.3355505466461182.
# Better model found at epoch 9 with valid_loss value: 1.3330435752868652.
# Better model found at epoch 10 with valid_loss value: 1.3328150510787964.
# Better model found at epoch 112 with valid_loss value: 1.3323487043380737.
# Better model found at epoch 127 with valid_loss value: 1.3284796476364136.
# Better model found at epoch 128 with valid_loss value: 1.3268134593963623.
# Better model found at epoch 129 with valid_loss value: 1.3231574296951294.
# Better model found at epoch 131 with valid_loss value: 1.3188222646713257.
# Better model found at epoch 133 with valid_loss value: 1.3161487579345703.
# Better model found at epoch 137 with valid_loss value: 1.315181851387024.
# Better model found at epoch 141 with valid_loss value: 1.3111234903335571.
# Better model found at epoch 142 with valid_loss value: 1.3072259426116943.
# Better model found at epoch 147 with valid_loss value: 1.3034275770187378.
# Better model found at epoch 151 with valid_loss value: 1.299316167831421.
# Better model found at epoch 154 with valid_loss value: 1.2968379259109497.
# Better model found at epoch 167 with valid_loss value: 1.2895195484161377.
# Better model found at epoch 171 with valid_loss value: 1.2889255285263062.

# %%
from fastai.callbacks import ReduceLROnPlateauCallback

# %%
cb = ReduceLROnPlateauCallback(learn, patience=5, factor=0.5)

# %%
import warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    learn.fit_one_cycle(200, 1e-3, callbacks=SaveModelCallback(learn, name='resnet_18_focal_loss2'), wd=0.1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.712098</td>
#       <td>2.820930</td>
#       <td>0.402000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.692564</td>
#       <td>2.119849</td>
#       <td>0.521300</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.675956</td>
#       <td>1.973245</td>
#       <td>0.549700</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.653836</td>
#       <td>1.911193</td>
#       <td>0.561600</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.629140</td>
#       <td>1.864846</td>
#       <td>0.570300</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.599716</td>
#       <td>1.826674</td>
#       <td>0.577200</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.572340</td>
#       <td>1.791006</td>
#       <td>0.584600</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.543894</td>
#       <td>1.754567</td>
#       <td>0.590800</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.517390</td>
#       <td>1.720562</td>
#       <td>0.598500</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.486276</td>
#       <td>1.685708</td>
#       <td>0.608100</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.454514</td>
#       <td>1.651168</td>
#       <td>0.614800</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.426095</td>
#       <td>1.621183</td>
#       <td>0.620700</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.395985</td>
#       <td>1.591150</td>
#       <td>0.627500</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.369391</td>
#       <td>1.565963</td>
#       <td>0.632200</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.345508</td>
#       <td>1.543875</td>
#       <td>0.636400</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.320001</td>
#       <td>1.522955</td>
#       <td>0.638600</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.298773</td>
#       <td>1.504365</td>
#       <td>0.642300</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.280633</td>
#       <td>1.486313</td>
#       <td>0.648200</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.261242</td>
#       <td>1.468815</td>
#       <td>0.653600</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.244315</td>
#       <td>1.455703</td>
#       <td>0.657000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1
# Better model found at epoch 9 with valid_loss value: 1.6857081651687622.
# Better model found at epoch 10 with valid_loss value: 1.651167631149292.
# Better model found at epoch 11 with valid_loss value: 1.6211827993392944.
# Better model found at epoch 12 with valid_loss value: 1.5911500453948975.
# Better model found at epoch 13 with valid_loss value: 1.565962791442871.
# Better model found at epoch 14 with valid_loss value: 1.5438753366470337.
# Better model found at epoch 15 with valid_loss value: 1.522955060005188.
# Better model found at epoch 16 with valid_loss value: 1.504365086555481.
# Better model found at epoch 17 with valid_loss value: 1.4863125085830688.
# Better model found at epoch 18 with valid_loss value: 1.4688149690628052.
# Better model found at epoch 19 with valid_loss value: 1.4557031393051147.
# Better model found at epoch 20 with valid_loss value: 1.4427672624588013.
# Better model found at epoch 21 with valid_loss value: 1.4315696954727173.
# Better model found at epoch 22 with valid_loss value: 1.4195982217788696.
# Better model found at epoch 23 with valid_loss value: 1.4101544618606567.
# Better model found at epoch 24 with valid_loss value: 1.4018876552581787.
# Better model found at epoch 25 with valid_loss value: 1.3891485929489136.
# Better model found at epoch 26 with valid_loss value: 1.3835153579711914.
# Better model found at epoch 27 with valid_loss value: 1.372590184211731.
# Better model found at epoch 28 with valid_loss value: 1.3718478679656982.
# Better model found at epoch 29 with valid_loss value: 1.362945318222046.
# Better model found at epoch 30 with valid_loss value: 1.358189582824707.
# Better model found at epoch 31 with valid_loss value: 1.3560130596160889.
# Better model found at epoch 32 with valid_loss value: 1.3537200689315796.
# Better model found at epoch 33 with valid_loss value: 1.3427823781967163.
# Better model found at epoch 34 with valid_loss value: 1.3364554643630981.
# Better model found at epoch 36 with valid_loss value: 1.3279885053634644.
# Better model found at epoch 40 with valid_loss value: 1.3229091167449951.
# Better model found at epoch 41 with valid_loss value: 1.3219226598739624.
# Better model found at epoch 43 with valid_loss value: 1.3161197900772095.
# Better model found at epoch 44 with valid_loss value: 1.3124357461929321.
# Better model found at epoch 46 with valid_loss value: 1.3084120750427246.
# Better model found at epoch 47 with valid_loss value: 1.3076375722885132.
# Better model found at epoch 50 with valid_loss value: 1.2988486289978027.
# Better model found at epoch 127 with valid_loss value: 1.2973599433898926.
# Better model found at epoch 131 with valid_loss value: 1.2934035062789917.
# Better model found at epoch 142 with valid_loss value: 1.2853212356567383.
# Better model found at epoch 148 with valid_loss value: 1.2734287977218628.
# Better model found at epoch 159 with valid_loss value: 1.2654660940170288.
# Better model found at epoch 164 with valid_loss value: 1.2609281539916992.

# %%
learn.save('focal2')

# %%
from fastai.vision import ClassificationInterpretation

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(10, heatmap=True)

# %%
learn.fit_one_cycle(220, 6e-3, callbacks=SaveModelCallback(learn, name='resnet18_96__'), start_epoch=180, wd=0.1)
# Out:
# Model resnet18_96___179 not found.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='11' class='' max='40', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       27.50% [11/40 1:58:01<5:11:10]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>180</td>
#       <td>1.109538</td>
#       <td>1.212131</td>
#       <td>0.291400</td>
#       <td>0.708600</td>
#       <td>10:31</td>
#     </tr>
#     <tr>
#       <td>181</td>
#       <td>1.123748</td>
#       <td>1.206399</td>
#       <td>0.291200</td>
#       <td>0.708800</td>
#       <td>10:27</td>
#     </tr>
#     <tr>
#       <td>182</td>
#       <td>1.123520</td>
#       <td>1.196451</td>
#       <td>0.286100</td>
#       <td>0.713900</td>
#       <td>10:33</td>
#     </tr>
#     <tr>
#       <td>183</td>
#       <td>1.123557</td>
#       <td>1.203960</td>
#       <td>0.287800</td>
#       <td>0.712200</td>
#       <td>10:37</td>
#     </tr>
#     <tr>
#       <td>184</td>
#       <td>1.120785</td>
#       <td>1.189389</td>
#       <td>0.283300</td>
#       <td>0.716700</td>
#       <td>10:43</td>
#     </tr>
#     <tr>
#       <td>185</td>
#       <td>1.120251</td>
#       <td>1.191710</td>
#       <td>0.284500</td>
#       <td>0.715500</td>
#       <td>10:46</td>
#     </tr>
#     <tr>
#       <td>186</td>
#       <td>1.121703</td>
#       <td>1.191914</td>
#       <td>0.283900</td>
#       <td>0.716100</td>
#       <td>11:08</td>
#     </tr>
#     <tr>
#       <td>187</td>
#       <td>1.112743</td>
#       <td>1.173061</td>
#       <td>0.282100</td>
#       <td>0.717900</td>
#       <td>10:50</td>
#     </tr>
#     <tr>
#       <td>188</td>
#       <td>1.110120</td>
#       <td>1.180446</td>
#       <td>0.283800</td>
#       <td>0.716200</td>
#       <td>10:45</td>
#     </tr>
#     <tr>
#       <td>189</td>
#       <td>1.114519</td>
#       <td>1.180402</td>
#       <td>0.286400</td>
#       <td>0.713600</td>
#       <td>10:50</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>1.117613</td>
#       <td>1.156468</td>
#       <td>0.273300</td>
#       <td>0.726700</td>
#       <td>10:46</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='48', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Better model found at epoch 180 with valid_loss value: 1.2121307849884033.
# Better model found at epoch 181 with valid_loss value: 1.2063989639282227.
# Better model found at epoch 182 with valid_loss value: 1.1964513063430786.
# Better model found at epoch 184 with valid_loss value: 1.189388632774353.
# Better model found at epoch 187 with valid_loss value: 1.173061490058899.
# Better model found at epoch 190 with valid_loss value: 1.1564682722091675.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-7a32aa9053ad> in <module>
# ----> 1 learn.fit_one_cycle(220, 6e-3, callbacks=SaveModelCallback(learn, name='resnet18_96__'), start_epoch=180, wd=0.1)
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\fastai\train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, final_div, wd, callbacks, tot_epochs, start_epoch)
#      20     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor, pct_start=pct_start,
#      21                                        final_div=final_div, tot_epochs=tot_epochs, start_epoch=start_epoch))
# ---> 22     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      23
#      24 def lr_find(learn:Learner, start_lr:Floats=1e-7, end_lr:Floats=10, num_it:int=100, stop_div:bool=True, wd:float=None):
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\fastai\basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     198         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
#     199         if defaults.extra_callbacks is not None: callbacks += defaults.extra_callbacks
# --> 200         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     201
#     202     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\fastai\basic_train.py in fit(epochs, learn, callbacks, metrics)
#      97             cb_handler.set_dl(learn.data.train_dl)
#      98             cb_handler.on_epoch_begin()
# ---> 99             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
#     101                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\fastprogress\fastprogress.py in __iter__(self)
#      70         self.update(0)
#      71         try:
# ---> 72             for i,o in enumerate(self._gen):
#      73                 if i >= self.total: break
#      74                 yield o
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\fastai\basic_data.py in __iter__(self)
#      73     def __iter__(self):
#      74         "Process and returns items from `DataLoader`."
# ---> 75         for b in self.dl: yield self.proc_batch(b)
#      76
#      77     @classmethod
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     308     def __next__(self):
#     309         index = self._next_index()  # may raise StopIteration
# --> 310         data = self.dataset_fetcher.fetch(index)  # may raise StopIteration
#     311         if self.pin_memory:
#     312             data = _utils.pin_memory.pin_memory(data)
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\fastai\data_block.py in __getitem__(self, idxs)
#     648             else:                 x,y = self.item   ,0
#     649             if self.tfms or self.tfmargs:
# --> 650                 x = x.apply_tfms(self.tfms, **self.tfmargs)
#     651             if hasattr(self, 'tfms_y') and self.tfm_y and self.item is None:
#     652                 y = y.apply_tfms(self.tfms_y, **{**self.tfmargs_y, 'do_resolve':False})
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\fastai\vision\image.py in apply_tfms(self, tfms, do_resolve, xtra, size, resize_method, mult, padding_mode, mode, remove_out)
#     121                 if resize_method in (ResizeMethod.CROP,ResizeMethod.PAD):
#     122                     x = tfm(x, size=_get_crop_target(size,mult=mult), padding_mode=padding_mode)
# --> 123             else: x = tfm(x)
#     124         return x.refresh()
#     125
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\fastai\vision\image.py in __call__(self, x, *args, **kwargs)
#     516     def __call__(self, x:Image, *args, **kwargs)->Image:
#     517         "Randomly execute our tfm on `x`."
# --> 518         return self.tfm(x, *args, **{**self.resolved, **kwargs}) if self.do_run else x
#     519
#     520 def _resolve_tfms(tfms:TfmList):
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\fastai\vision\image.py in __call__(self, p, is_random, use_on_y, *args, **kwargs)
#     462     def __call__(self, *args:Any, p:float=1., is_random:bool=True, use_on_y:bool=True, **kwargs:Any)->Image:
#     463         "Calc now if `args` passed; else create a transform called prob `p` if `random`."
# --> 464         if args: return self.calc(*args, **kwargs)
#     465         else: return RandTransform(self, kwargs=kwargs, is_random=is_random, use_on_y=use_on_y, p=p)
#     466
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\fastai\vision\image.py in calc(self, x, *args, **kwargs)
#     467     def calc(self, x:Image, *args:Any, **kwargs:Any)->Image:
#     468         "Apply to image `x`, wrapping it if necessary."
# --> 469         if self._wrap: return getattr(x, self._wrap)(self.func, *args, **kwargs)
#     470         else:          return self.func(x, *args, **kwargs)
#     471
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\fastai\vision\image.py in lighting(self, func, *args, **kwargs)
#     165     def lighting(self, func:LightingFunc, *args:Any, **kwargs:Any):
#     166         "Equivalent to `image = sigmoid(func(logit(image)))`."
# --> 167         self.logit_px = func(self.logit_px, *args, **kwargs)
#     168         return self
#     169
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\fastai\vision\image.py in logit_px(self)
#     204     def logit_px(self)->LogitTensorImage:
#     205         "Get logit(image.px)."
# --> 206         if self._logit_px is None: self._logit_px = logit_(self.px)
#     207         return self._logit_px
#     208     @logit_px.setter
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\fastai\vision\image.py in px(self)
#     143     def px(self)->TensorImage:
#     144         "Get the tensor pixel buffer."
# --> 145         self.refresh()
#     146         return self._px
#     147     @px.setter
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\fastai\vision\image.py in refresh(self)
#     130             self._logit_px = None
#     131         if self._affine_mat is not None or self._flow is not None:
# --> 132             self._px = _grid_sample(self._px, self.flow, **self.sample_kwargs)
#     133             self.sample_kwargs = {}
#     134             self._flow = None
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\fastai\vision\image.py in _grid_sample(x, coords, mode, padding_mode, remove_out)
#     524 def _grid_sample(x:TensorImage, coords:FlowField, mode:str='bilinear', padding_mode:str='reflection', remove_out:bool=True)->TensorImage:
#     525     "Resample pixels in `coords` from `x` by `mode`, with `padding_mode` in ('reflection','border','zeros')."
# --> 526     coords = coords.flow.permute(0, 3, 1, 2).contiguous().permute(0, 2, 3, 1) # optimize layout for grid_sample
#     527     if mode=='bilinear': # hack to get smoother downwards resampling
#     528         mn,mx = coords.min(),coords.max()
#
# KeyboardInterrupt:
